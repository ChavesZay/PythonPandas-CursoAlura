# %% [markdown]
# <a href="https://colab.research.google.com/github/ChavesZay/PythonPandas-CursoAlura/blob/main/Formas_de_Seleccion__3_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formas de selección

# %%
import pandas as pd

# %%
'11 12 13 14'.split() #Split() divide la cadena de texto en elementos unicos dentro de una lista
# Out:
# ['11', '12', '13', '14']

# %%
data=[(1,2,3,4),(5,6,7,8),(8,10,11,12),(13,14,15,16)]
df=pd.DataFrame(data,'11 12 13 14'.split(),'c1 c2 c3 c4'.split())
df
# Out:
#     c1  c2  c3  c4
# 11   1   2   3   4
# 12   5   6   7   8
# 13   8  10  11  12
# 14  13  14  15  16

# %%
df['c1']
# Out:
# 11     1
# 12     5
# 13     8
# 14    13
# Name: c1, dtype: int64

# %%
type(df['c1'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Selecciones especificas
# ### Particiones
# Seleccion de solo algunas columnas y filas, por lo cual debemos particionar

# %%
df['c1'] #Para ver solo una columna

# %%
(df[['c1','c2']]) #Seleccionar 2 o más columnas
# Out:
#     c1  c2
# 11   1   2
# 12   5   6
# 13   8  10
# 14  13  14

# %%
type(df[['c1','c2']])
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#     c1  c2  c3  c4
# 11   1   2   3   4
# 12   5   6   7   8
# 13   8  10  11  12
# 14  13  14  15  16

# %%
df[1:3] #Seleccionar por indices, es con la posicion
# Out:
#     c1  c2  c3  c4
# 12   5   6   7   8
# 13   8  10  11  12

# %%
df[1:][['c1','c3']] #Seleccion porindice y por columnas
# Out:
#     c1  c3
# 12   5   7
# 13   8  11
# 14  13  15

# %%
df
# Out:
#     c1  c2  c3  c4
# 11   1   2   3   4
# 12   5   6   7   8
# 13   8  10  11  12
# 14  13  14  15  16

# %%
df.loc['13'] #Parametro nom de columnas (c1,c2,c3,c4,11,12,13,14)
# Out:
# c1     8
# c2    10
# c3    11
# c4    12
# Name: 13, dtype: int64

# %%
df.loc['11']
# Out:
# c1    1
# c2    2
# c3    3
# c4    4
# Name: 11, dtype: int64

# %%
df.loc[['13','12']]
# Out:
#     c1  c2  c3  c4
# 13   8  10  11  12
# 12   5   6   7   8

# %%
df
# Out:
#     c1  c2  c3  c4
# 11   1   2   3   4
# 12   5   6   7   8
# 13   8  10  11  12
# 14  13  14  15  16

# %%
df.loc['11','c2'] #Devuelve el valor de interseccion entre la columna y la fila
# Out:
# 2

# %%
#iloc[] se coloca la posicion de las filas y columnas
df.iloc[0,1]  #La misma interseccion, pero diferente metodo
# Out:
# 2

# %%
df.loc[['13','11'],['c4','c1']] #Primer para metro los nom de las filas y segundo parametro nom de las columnas
# Out:
#     c4  c1
# 13  12   8
# 11   4   1

# %%
df
# Out:
#     c1  c2  c3  c4
# 11   1   2   3   4
# 12   5   6   7   8
# 13   8  10  11  12
# 14  13  14  15  16

# %%
df.iloc[[2,0],[3,0]]
# Out:
#     c4  c1
# 13  12   8
# 11   4   1
