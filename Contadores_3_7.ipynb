# %% [markdown]
# <a href="https://colab.research.google.com/github/ChavesZay/PythonPandas-CursoAlura/blob/main/Contadores_3_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
serie=pd.Series(list('asdaesdaesdasesda'))
serie
# Out:
# 0     a
# 1     s
# 2     d
# 3     a
# 4     e
# 5     s
# 6     d
# 7     a
# 8     e
# 9     s
# 10    d
# 11    a
# 12    s
# 13    e
# 14    s
# 15    d
# 16    a
# dtype: object

# %%
serie.unique() #Metodo que muestra los valores unicos de la serie
# Out:
# array(['a', 's', 'd', 'e'], dtype=object)

# %%
serie.value_counts() #Metodo que muestra la frecuencia de cada elemento de la serie
# Out:
# a    5
# s    5
# d    4
# e    3
# dtype: int64

# %%
datos=pd.read_csv('alquiler.csv',sep=';')
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2     Local comercial          Ate        0         4       0   150   5200.0
# 3        Departamento   Pachacámac        1         0       0    15    800.0
# 4        Departamento          Ate        1         0       0    48    800.0
# 5        Departamento     Barranco        3         1       0    70   1200.0
# 6        Departamento        Comas        2         0       0    50   1300.0
# 7  Casa en condominio          Ate        5         4       5   750  22000.0
# 8  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 9     Local comercial   Pachacámac        0         3       0   695  35000.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# ...

# %% [markdown]
# **Cuantos tipos de locales hay?**

# %%
datos['Tipo'].unique()
# Out:
# array(['Habitación', 'Casa', 'Local comercial', 'Departamento',
#        'Casa en condominio', 'Edificio completo', 'Flat', 'Tienda/Salón',
#        'Almacén', 'Casa comercial', 'Casa de villa', 'Terreno', 'Cochera',
#        'Loft', 'Tienda en Centro Comercial', 'Chacra',
#        'Terreno em condominio', 'Oficina', 'Chalet', 'Studio', 'Hotel',
#        'Local industrial'], dtype=object)

# %% [markdown]
# **La Frecuencia de los elementos de los tipos de locales**

# %%
datos.Tipo.value_counts()
# Out:
# Departamento                  19532
# Local comercial                6815
# Tienda/Salón                   1426
# Casa en condominio              996
# Casa                            967
# Habitación                      836
# Almacén                         623
# Flat                            476
# Edificio completo               301
# Casa comercial                  265
# Casa de villa                   249
# Tienda en Centro Comercial      247
# Cochera                          82
# Terreno                          70
# Loft                             51
# Oficina                          10
# Terreno em condominio             5
# Studio                            4
# Hotel                             2
# Chacra                            1
# Chalet                            1
# Local industrial                  1
# Name: Tipo, dtype: int64

# %% [markdown]
# ## Ejercicio Extra

# %%
m1 = 'CCcCCccCCCccCcCccCcCcCCCcCCcccCCcCcCcCcccCCcCcccCc'
m2 = 'CCCCCccCccCcCCCCccCccccCccCccCCcCccCcCcCCcCccCccCc'
m3 = 'CccCCccCcCCCCCCCCCCcccCccCCCCCCccCCCcccCCCcCCcccCC'
m4 = 'cCCccCCccCCccCCccccCcCcCcCcCcCcCCCCccccCCCcCCcCCCC'
m5 = 'CCCcCcCcCcCCCcCCcCcCCccCcCCcccCccCCcCcCcCcCcccccCc'

# %%
eventos = {'m1': list(m1), 'm2': list(m2), 'm3': list(m3),  'm4': list(m4), 'm5': list(m5)}
eventos
# Out:
# {'m1': ['C',
#   'C',
#   'c',
#   'C',
#   'C',
#   'c',
#   'c',
#   'C',
#   'C',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c',
#   'C',
#   'c',
#   'C',
#   'C',
#   'C',
#   'c',
#   'C',
#   'C',
#   'c',
#   'c',
#   'c',
#   'C',
#   'C',
#   'c',
#   'C',
#   'c',
#   'C',
#   'c',
#   'C',
#   'c',
#   'c',
#   'c',
#   'C',
#   'C',
#   'c',
#   'C',
#   'c',
#   'c',
#   'c',
#   'C',
#   'c'],
#  'm2': ['C',
#   'C',
#   'C',
#   'C',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c',
#   'C',
#   'C',
#   'C',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c',
#   'c',
#   'c',
#   'c',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c',
#   'c',
#   'C',
#   'C',
#   'c',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c',
#   'C',
#   'c',
#   'C',
#   'C',
#   'c',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c',
#   'c',
#   'C',
#   'c'],
#  'm3': ['C',
#   'c',
#   'c',
#   'C',
#   'C',
#   'c',
#   'c',
#   'C',
# ...

# %%
monedas = pd.DataFrame(eventos)
monedas
# Out:
#    m1 m2 m3 m4 m5
# 0   C  C  C  c  C
# 1   C  C  c  C  C
# 2   c  C  c  C  C
# 3   C  C  C  c  c
# 4   C  C  C  c  C
# 5   c  c  c  C  c
# 6   c  c  c  C  C
# 7   C  C  C  c  c
# 8   C  c  c  c  C
# 9   C  c  C  C  c
# 10  c  C  C  C  C
# 11  c  c  C  c  C
# 12  C  C  C  c  C
# 13  c  C  C  C  c
# 14  C  C  C  C  C
# 15  c  C  C  c  C
# 16  c  c  C  c  c
# 17  C  c  C  c  C
# 18  c  C  C  c  c
# 19  C  c  c  C  C
# 20  c  c  c  c  C
# 21  C  c  c  C  c
# 22  C  c  C  c  c
# 23  C  C  c  C  C
# 24  c  c  c  c  c
# 25  C  c  C  C  C
# 26  C  C  C  c  C
# 27  c  c  C  C  c
# 28  c  c  C  c  c
# 29  c  C  C  C  c
# 30  C  C  C  c  C
# 31  C  c  c  C  c
# 32  c  C  c  C  c
# 33  C  c  C  C  C
# 34  c  c  C  C  C
# 35  C  C  C  c  c
# 36  c  c  c  c  C
# 37  C  C  c  c  c
# 38  c  c  c  c  C
# 39  c  C  C  C  c
# 40  c  C  C  C  C
# 41  C  c  C  C  c
# 42  C  C  c  c  C
# 43  c  c  C  C  c
# 44  C  c  C  C  c
# 45  c  C  c  c  c
# 46  c  c  c  C  c
# 47  c  c  c  C  c
# 48  C  C  C  C  C
# ...

# %%
df = pd.DataFrame(data = ['Cara', 'Crown'],
                    index = ['c', 'C'],
                    columns = ['Faces'])

df
# Out:
#    Faces
# c   Cara
# C  Crown

# %%
for item in monedas:
    df = pd.concat([df, monedas[item].value_counts()],
                    axis = 1)
df
# Out:
#    Faces  m1  m2  m3  m4  m5
# c   Cara  25  26  19  23  25
# C  Crown  25  24  31  27  25
